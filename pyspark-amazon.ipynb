# %%
spark.version
# Out:
# '3.1.3'

# %%
import os
import shutil
import pandas as pd
# import sh
from pyspark.sql.functions import *
#from pyspark.sql import functions as F
from pyspark.sql.types import *

# %%
pd.set_option("max_colwidth", 100)

# %% [markdown]
# #### Set-up COS functions for GCS

# %%
from google.cloud import storage

# %%
# List all files in given COS directory
def list_blobs(bucket_name, folder_name):
    gcs_client = storage.Client()
    bucket = gcs_client.bucket(bucket_name)
    blobs = list(bucket.list_blobs(prefix=folder_name))

    for blob in blobs:
        print(blob.name + '\t' + str(blob.size))

# %%
# List all files in given COS directory
def list_blobs_pd(bucket_name, folder_name):
    gcs_client = storage.Client()
    bucket = gcs_client.bucket(bucket_name)
    blobs = list(bucket.list_blobs(prefix=folder_name))

    blob_name = []
    blob_size = []
    
    for blob in blobs:
        blob_name.append(blob.name)
        blob_size.append(blob.size)

    blobs_df = pd.DataFrame(list(zip(blob_name, blob_size)), columns=['Name','Size'])

    blobs_df.style.format({"Size": "{:,.0f}"}) 
    
    return blobs_df

# %%
# Delete folder from COS bucket
def delete_folder(bucket_name, folder_name):
    gcs_client = storage.Client()
    bucket = gcs_client.bucket(bucket_name)
    blobs = list(bucket.list_blobs(prefix=folder_name))

    for blob in blobs:
        blob.delete()

# %%
# Reading data from open bucket, avaible to all students
bucket_read = 'msca-bdp-amazon'

# Saving results into individual bucket, students must update to their own bucket
bucket_write = 'msca-bdp-data-shared'

# %% [markdown]
# ### Check source data in COS

# %%
list_blobs_pd(bucket_read, 'amazon_reviews')
# Out:
#                                                                    Name  \
# 0                                                       amazon_reviews/
# 1                    amazon_reviews/amazon_reviews_us_Apparel_v1_00.tsv
# 2                 amazon_reviews/amazon_reviews_us_Automotive_v1_00.tsv
# 3                       amazon_reviews/amazon_reviews_us_Baby_v1_00.tsv
# 4                     amazon_reviews/amazon_reviews_us_Beauty_v1_00.tsv
# 5                      amazon_reviews/amazon_reviews_us_Books_v1_00.tsv
# 6                      amazon_reviews/amazon_reviews_us_Books_v1_01.tsv
# 7                      amazon_reviews/amazon_reviews_us_Books_v1_02.tsv
# 8                     amazon_reviews/amazon_reviews_us_Camera_v1_00.tsv
# 9     amazon_reviews/amazon_reviews_us_Digital_Ebook_Purchase_v1_00.tsv
# 10    amazon_reviews/amazon_reviews_us_Digital_Ebook_Purchase_v1_01.tsv
# 11    amazon_reviews/amazon_reviews_us_Digital_Music_Purchase_v1_00.tsv
# 12          amazon_reviews/amazon_reviews_us_Digital_Software_v1_00.tsv
# 13    amazon_reviews/amazon_reviews_us_Digital_Video_Download_v1_00.tsv
# 14       amazon_reviews/amazon_reviews_us_Digital_Video_Games_v1_00.tsv
# 15               amazon_reviews/amazon_reviews_us_Electronics_v1_00.tsv
# 16                 amazon_reviews/amazon_reviews_us_Furniture_v1_00.tsv
# 17                 amazon_reviews/amazon_reviews_us_Gift_Card_v1_00.tsv
# 18                   amazon_reviews/amazon_reviews_us_Grocery_v1_00.tsv
# 19      amazon_reviews/amazon_reviews_us_Health_Personal_Care_v1_00.tsv
# 20        amazon_reviews/amazon_reviews_us_Home_Entertainment_v1_00.tsv
# 21          amazon_reviews/amazon_reviews_us_Home_Improvement_v1_00.tsv
# 22                      amazon_reviews/amazon_reviews_us_Home_v1_00.tsv
# 23                   amazon_reviews/amazon_reviews_us_Jewelry_v1_00.tsv
# 24                   amazon_reviews/amazon_reviews_us_Kitchen_v1_00.tsv
# 25           amazon_reviews/amazon_reviews_us_Lawn_and_Garden_v1_00.tsv
# 26                   amazon_reviews/amazon_reviews_us_Luggage_v1_00.tsv
# 27          amazon_reviews/amazon_reviews_us_Major_Appliances_v1_00.tsv
# 28               amazon_reviews/amazon_reviews_us_Mobile_Apps_v1_00.tsv
# 29        amazon_reviews/amazon_reviews_us_Mobile_Electronics_v1_00.tsv
# 30                     amazon_reviews/amazon_reviews_us_Music_v1_00.tsv
# 31       amazon_reviews/amazon_reviews_us_Musical_Instruments_v1_00.tsv
# 32           amazon_reviews/amazon_reviews_us_Office_Products_v1_00.tsv
# 33                  amazon_reviews/amazon_reviews_us_Outdoors_v1_00.tsv
# 34                        amazon_reviews/amazon_reviews_us_PC_v1_00.tsv
# 35  amazon_reviews/amazon_reviews_us_Personal_Care_Appliances_v1_00.tsv
# 36              amazon_reviews/amazon_reviews_us_Pet_Products_v1_00.tsv
# 37                     amazon_reviews/amazon_reviews_us_Shoes_v1_00.tsv
# 38                  amazon_reviews/amazon_reviews_us_Software_v1_00.tsv
# 39                    amazon_reviews/amazon_reviews_us_Sports_v1_00.tsv
# 40                     amazon_reviews/amazon_reviews_us_Tools_v1_00.tsv
# 41                      amazon_reviews/amazon_reviews_us_Toys_v1_00.tsv
# 42                 amazon_reviews/amazon_reviews_us_Video_DVD_v1_00.tsv
# 43               amazon_reviews/amazon_reviews_us_Video_Games_v1_00.tsv
# 44                     amazon_reviews/amazon_reviews_us_Video_v1_00.tsv
# 45                   amazon_reviews/amazon_reviews_us_Watches_v1_00.tsv
# 46                  amazon_reviews/amazon_reviews_us_Wireless_v1_00.tsv
#
#           Size
# 0            0
# 1   1971061630
# 2   1350294084
# 3    872274720
# 4   2152186111
# 5   6699171766
# 6   6703921864
# 7   3238702530
# 8   1100169988
# 9   6696964946
# 10  3224038446
# 11   628880453
# 12    53855391
# 13  1288048833
# 14    73154460
# 15  1725988504
# 16   366979553
# 17    39977611
# 18   956224754
# 19  2422088742
# 20   500303241
# 21  1202422006
# 22  2496148207
# 23   617809191
# 24  2218102275
# 25  1148784380
# 26   150519467
# 27    62977388
# 28  1384889812
# 29    58221236
# 30  3671037159
# 31   475220114
# 32  1243069057
# 33  1061801717
# 34  3648888910
# 35    44891575
# 36  1227951681
# 37  1570176560
# 38   249565371
# 39  2007024927
# 40   788203941
# 41  1962834272
# 42  3708889477
# 43  1204902329
# 44   337970606
# 45   412542975
# 46  4198056580

# %%
path = "gs://msca-bdp-amazon/amazon_reviews/amazon*.tsv"

# %%
amazon_df = spark.read.csv(path, header='true', inferSchema='true', sep='\t', quote='"')

# %%
spark.conf.set("spark.sql.repl.eagerEval.enabled",True)

# %%
amazon_df.printSchema()
# Out:
# root
#  |-- marketplace: string (nullable = true)
#  |-- customer_id: integer (nullable = true)
#  |-- review_id: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- product_parent: integer (nullable = true)
#  |-- product_title: string (nullable = true)
#  |-- product_category: string (nullable = true)
#  |-- star_rating: string (nullable = true)
#  |-- helpful_votes: integer (nullable = true)
#  |-- total_votes: integer (nullable = true)
#  |-- vine: string (nullable = true)
#  |-- verified_purchase: string (nullable = true)
#  |-- review_headline: string (nullable = true)
#  |-- review_body: string (nullable = true)
#  |-- review_date: string (nullable = true)

# %% [markdown]
# ## Question 1. Which product category gets most reviews?

# %% [markdown]
# ### Answer: Digital_Ebook_Purchase with 13,718,761 reviews

# %% [markdown]
# To clean the data, I will only look at purchases that are verified

# %%
amazon_df = amazon_df.filter('verified_purchase = "Y"')

# %%
amazon_df.groupBy('product_category').agg(count('review_id')).orderBy('count(review_id)',ascending=False).show(1,False)
# Out:
# [Stage 76:================================================>       (18 + 3) / 21]
# +----------------------+----------------+
# |product_category      |count(review_id)|
# +----------------------+----------------+
# |Digital_Ebook_Purchase|13718761        |
# +----------------------+----------------+
# only showing top 1 row

# %% [markdown]
# ## Question 2. Which product category gets highest / lowest review star ratings?

# %% [markdown]
# ### Answer: Gift Card has the highest star ratings (4.7461), while Digital Software has the lowest star ratings (3.5430)

# %%
amazon_df = amazon_df.withColumn("star_rating", amazon_df["star_rating"].cast(DoubleType())).\
withColumn("review_date",amazon_df['review_date'].cast('date'))

# %%
df2 = amazon_df.groupBy('product_category').agg(avg('star_rating'))
# Out:
# [Stage 91:=========================>                           (287 + 22) / 598]

# %%
df2.orderBy('avg(star_rating)',ascending = False).show(1,False)
# Out:
# [Stage 92:=====================================================>(597 + 1) / 598]
# +----------------+------------------+
# |product_category|avg(star_rating)  |
# +----------------+------------------+
# |Gift Card       |4.7461078196439335|
# +----------------+------------------+
# only showing top 1 row

# %%
df2.orderBy('avg(star_rating)',ascending = True).show(1,False)
# Out:
# [Stage 97:=====================================================>(596 + 2) / 598]
# +----------------+-----------------+
# |product_category|avg(star_rating) |
# +----------------+-----------------+
# |Digital_Software|3.543014394580864|
# +----------------+-----------------+
# only showing top 1 row

# %% [markdown]
# ## Question 3. Do you see seasonality in reviews?

# %%
Is every product category getting consistent number of reviews throughout the year?
Any product categories that are getting more reviews during certain times of the year?  If yes, which product categories and what times of the year?

# %%
amazon_df = amazon_df.withColumn("review_m_y", date_format(amazon_df["review_date"],"yyyy-MM")).\
                    withColumn("review_m", date_format(amazon_df["review_date"],"MM")).\
                    withColumn("review_y", date_format(amazon_df["review_date"],"yyyy"))

# %%
amazon_df.groupBy('review_m').agg(count('review_id'))
# Out:
# +----------+----------------+
# |review_m_y|count(review_id)|
# +----------+----------------+
# |      null|            7487|
# |   1995-11|               1|
# |   1995-12|               1|
# |   1996-02|               1|
# |   1996-05|               1|
# |   1996-06|               8|
# |   1996-07|               8|
# |   1996-08|               2|
# |   1996-09|               9|
# |   1996-10|              14|
# |   1996-11|               5|
# |   1996-12|              23|
# |   1997-01|              26|
# |   1997-02|              28|
# |   1997-03|              51|
# |   1997-04|              47|
# |   1997-05|              41|
# |   1997-06|              83|
# |   1997-07|             101|
# |   1997-08|             107|
# +----------+----------------+
# only showing top 20 rows

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
my_plot = amazon_df.plot(kind='line',x='review_m', y='review_y', legend=None, title="Height by Gender")
